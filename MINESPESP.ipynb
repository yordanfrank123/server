# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1




version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

if server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
if server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

if server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version



jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

elif server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

elif server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def ejecutar_comando(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

# Purga versiones anteriores de OpenJDK
ejecutar_comando('sudo apt-get purge openjdk* -y')

# Instala OpenJDK 17
ejecutar_comando('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "playit":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "tu token aqui" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))

elif tunnel_service == "playit":

    ! curl -SsL https://playit-cloud.github.io/ppa/key.gpg | sudo apt-key add -
    ! sudo curl -SsL -o /etc/apt/sources.list.d/playit-cloud.list https://playit-cloud.github.io/ppa/playit-cloud.list
    ! sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg installed" || echo "Failed to install playit"
    print('Starting server...')
    ! playit & java $memory_allocation $server_flags -jar $jar_name nogui

print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
    
    if forgepreversion:
    
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
    
    else:
    
        print("No se encontraron archivos en el directorio Forge.")
    
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o purpur

else:
    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui   

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # asdasdasdasfasfd
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      help.yml	    ops.json	       usernamecache.json
# banned-players.json  journeymap     patchouli_books    vanilla.jar
# bukkit.yml	     libraries	    permissions.yml    versions
# colabconfig.json     logs	    plugins	       whitelist.json
# commands.yml	     mods	    server.properties
# defaultconfigs	     mohist-config  spigot.yml
# eula.txt	     mohist.jar     usercache.json
# OpenJDK 17 instalado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.20.1-580, Java(21.0.2) 65.0 PID: 205408
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 1.20.1-594 but you have 1.20.1-580. The latest version has been built on 2024-03-07 01:23:18. You should update to fix recent bugs!
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [03:45:07 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.20, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [03:45:07 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [03:45:07 WARN]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/fml.toml is not correct. Correcting
# [03:45:07 INFO]: Incorrect key [earlyWindowSkipGLVersions] was corrected from null to []
# [03:45:07 INFO]: Incorrect key [earlyWindowSquir] was corrected from null to false
# [03:45:12 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [03:45:12 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [03:45:13 WARN]: Attempted to select two dependency jars from JarJar which have the same identification: Mod File:  and Mod File: . Using Mod File:
# [03:45:13 WARN]: Attempted to select a dependency jar for JarJar which was passed in as source: geckolib. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/geckolib-forge-1.20.1-4.4.2.jar
# [03:45:13 INFO]: Found 20 dependencies adding them to mods collection
# [03:45:16 INFO]: Compatibility level set to JAVA_17
# [03:45:16 ERROR]: Mixin config celestisynth.mixins.json does not specify "minVersion" property
# [03:45:17 INFO]: Successfully loaded Mixin Connector [com.sonicether.soundphysics.MixinConnector]
# [03:45:17 INFO]: Successfully loaded Mixin Connector [com.robertx22.temporary_spawners.MixinConnector]
# [03:45:17 INFO]: Successfully loaded Mixin Connector [com.aizistral.enigmaticlegacy.MixinConnector]
# [03:45:17 INFO]: Successfully loaded Mixin Connector [com.robertx22.library_of_exile.main.MixinConnector]
# Connecting library_of_exile Mixins
# [03:45:17 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [03:45:17 WARN]: Reference map 'l2artifacts.refmap.json' for l2artifacts.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:45:17 WARN]: Reference map 'handcrafted-forge-1.20.1-forge-refmap.json' for handcrafted.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:45:17 WARN]: Reference map 'CerbonsAPI-Forge-1.20.1-forge-refmap.json' for cerbons_api.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:45:17 WARN]: Reference map 'octolib.refmap.json' for octolib.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:45:17 WARN]: Reference map 'simplyswords-forge-refmap.json' for simplyswords.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:45:17 WARN]: Reference map 'coroutil.refmap.json' for coroutil.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:45:17 INFO]: Loading 120 mods:
# 	- advancednetherite 2.0.2
# 	- alexscaves 1.1.3
# 	- alexsmobs 1.22.7
# 	- appleskin 2.5.1+mc1.20.1
# 	- aquamirae 6.API15
# 	- architectury 9.1.13
# 	- ars_nouveau 4.9.0
# 	- artifacts 9.2.2
# 	- balm 7.2.1
# 	- bettercombat 1.8.4+1.20.1
# 	- betterf3 7.0.2
# 	- bookshelf 20.1.8
# 	- bosses_of_mass_destruction 1.1.2
# 	- bounties 1.0.0
# 	- bounties_traders 1.0.0
# 	- bwrtherain 2.2.7
# 	- caelus 3.1.0+1.20
# 	- carryon 2.1.2.7
# 	- cataclysm 1.0
# 	- cataclysmiccombat 1.2
# 	- celestisynth 1.20.1-1.2.1
# 	- cerbons_api 1.1.0
# 	- citadel 2.5.4
# 	- cloth_config 11.1.118
# 	- coroutil 1.20.1-1.3.7
# 	- corpse 1.20.1-1.0.9
# 	- cosmeticarmorreworked 1.20.1-v1a
# 	- create 0.5.1.f
# 	- create_sa 2.0.4.
# 	- creation_and_adventure 1.0.6
# 	- curios 5.4.7+1.20.1
# 	- curseofpandora 2.4.6
# 	- cutthrough 8.0.1
# 	- devices 0.8.2
# 	- display 1.2.2
# 	- dungeons_arise 2.1.58-1.20.x
# 	- dungeons_arise_seven_seas 1.0.2
# 	- dwm 1.1.1
# 	- easy_villagers 1.20.1-1.1.3
# 	- enchdesc 17.0.13
# 	- endlessbiomes 1.0.0
# 	- enhancedai 2.2.0
# 	- enigmaticlegacy 2.29.0
# 	- expandability 9.0.0
# 	- extra_compat 1.4.2
# 	- farmersdelight 1.20.1-1.2.4
# 	- fastleafdecay 31
# 	- ferritecore 6.0.1
# 	- flywheel 0.6.10-7
# 	- forbidden_arcanus 1.20.1-2.2.4
# 	- forge 47.2.20
# 	- geckolib 4.4.2
# 	- handcrafted 3.0.6
# 	- incendium 5.3.4
# 	- insanelib 1.12.1
# 	- invtweaks 1.0.0
# 	- jade 11.8.0
# 	- jei 15.3.0.1
# 	- journeymap 5.9.18
# 	- l2archery 2.4.11
# 	- l2artifacts 2.4.17
# 	- l2backpack 2.4.18
# 	- l2complements 2.4.29
# 	- l2damagetracker 0.2.6
# 	- l2hostility 2.4.17
# 	- l2itemselector 0.1.7
# 	- l2library 2.4.23
# 	- l2screentracker 0.1.4
# 	- l2tabs 0.2.6
# 	- l2weaponry 2.4.22
# 	- leavemybarsalone 8.0.0
# 	- letmedespawn 1.2.0
# 	- library_of_exile 1.4.1
# 	- lootr 0.7.31.77
# 	- maxhealthfix 12.0.2
# 	- minecraft 1.20.1
# 	- mixinextras 0.2.0-beta.8
# 	- mixinsquared 0.1.1
# 	- mohist 1.20.1
# 	- moonlight 1.20-2.9.13
# 	- moth_spider_dweller 1.3.1
# 	- mousetweaks 2.25
# 	- obscure_api 15
# 	- obscure_tooltips 2.2
# 	- octolib 0.2
# 	- pandora 0.1.4
# 	- patchouli 1.20.1-84-FORGE
# 	- placebo 8.6.0
# 	- playeranimator 1.0.2-rc1+1.20
# 	- playershops 1.1.2
# 	- puzzlesaccessapi 8.0.7
# 	- puzzleslib 8.1.16
# 	- quark 4.0-434
# 	- regions_unexplored 0.5.5
# 	- relics 0.5.3
# 	- resourcefullib 2.1.23
# 	- rpgsmw 7.61.20.1
# 	- securitycraft 1.9.8
# 	- simplyswords 1.53.0-1.20.1
# 	- simplywalk 0.4.1
# 	- sitmod 0.5.2
# 	- skin_changer 0.6.0
# 	- sound_physics_remastered 1.20.1-1.1.2
# 	- spelunkers_charm 3.5.3
# 	- stackablepotions 1.0.0
# 	- supplementaries 1.20-2.7.36
# 	- swordblockingmechanics 8.0.1
# 	- temporalapi 1.3.0
# 	- temporary_spawners 1.5.1
# 	- terrablender 3.0.1.4
# 	- the_awakening_of_the_elder_souls 0.0.6
# 	- underground_bunkers 1.0.3
# 	- valhelsia_core 1.1.1
# 	- valhelsia_furniture 1.1.2
# 	- valhelsia_structures 1.20.1-1.1.1
# 	- valoria 1.20.1-build-0.5.2.1_b
# 	- watut 1.20.1-1.1.0
# 	- waystones 14.1.3
# 	- wi_zoom 1.5-MC1.20.1-Forge
# 	- zeta 1.0-13
# [03:45:17 WARN]: Reference map 'itemselector.refmap.json' for l2itemselector.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:45:17 WARN]: Reference map 'Aquamirae.refmap.json' for aquamirae.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:45:17 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [03:45:17 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [03:45:18 ERROR]: Attempted to load class net/minecraft/client/gui/screens/Screen for invalid dist DEDICATED_SERVER
# [03:45:18 WARN]: Error loading class: net/minecraft/client/gui/screens/Screen (java.lang.RuntimeException: Attempted to load class net/minecraft/client/gui/screens/Screen for invalid dist DEDICATED_SERVER)
# [03:45:18 WARN]: @Mixin target net.minecraft.client.gui.screens.Screen was not found relics.mixins.json:MixinScreen
# [03:45:20 WARN]: Error loading class: com/mojang/blaze3d/audio/Channel (java.lang.ClassNotFoundException: com.mojang.blaze3d.audio.Channel)
# [03:45:20 WARN]: @Mixin target com.mojang.blaze3d.audio.Channel was not found assets/sound_physics_remastered/sound_physics_remastered.mixins.json:ChannelAccessor
# [03:45:20 WARN]: Error loading class: net/darkhax/darkutils/features/charms/CharmEffects (java.lang.ClassNotFoundException: net.darkhax.darkutils.features.charms.CharmEffects)
# [03:45:20 WARN]: Error loading class: com/brandon3055/csg/ModEventHandler (java.lang.ClassNotFoundException: com.brandon3055.csg.ModEventHandler)
# [03:45:20 WARN]: Error loading class: vazkii/quark/content/tweaks/module/AutomaticRecipeUnlockModule (java.lang.ClassNotFoundException: vazkii.quark.content.tweaks.module.AutomaticRecipeUnlockModule)
# [03:45:20 INFO]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.3.2).
# [03:45:22 INFO]: Mixing MixinLivingEntity from enigmaticlegacy.mixins.json into net.minecraft.world.entity.LivingEntity
# [03:45:22 INFO]: Mixing MixinPlayer from enigmaticlegacy.mixins.json into net.minecraft.world.entity.player.Player
# [03:45:22 INFO]: Mixing MixinMobEffect from enigmaticlegacy.mixins.json into net.minecraft.world.effect.MobEffect
# [03:45:24 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [03:45:24 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [03:45:24 INFO]: Mixing MixinItemStack from enigmaticlegacy.mixins.json into net.minecraft.world.item.ItemStack
# [03:45:24 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [03:45:24 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [03:45:24 INFO]: Mixing AccessorAbstractArrowEntity from enigmaticlegacy.mixins.json into net.minecraft.world.entity.projectile.AbstractArrow
# [03:45:24 INFO]: Mixing MixinEnchantmentContainer from enigmaticlegacy.mixins.json into net.minecraft.world.inventory.EnchantmentMenu
# [03:45:24 INFO]: Renaming synthetic method lambda$onEnchantedItem$0(Lnet/minecraft/world/item/ItemStack;Lnet/minecraft/world/inventory/EnchantmentMenu;ILnet/minecraft/world/entity/player/Player;ILnet/minecraft/world/level/Level;Lnet/minecraft/core/BlockPos;)V to md272da1$lambda$onEnchantedItem$0$0 in enigmaticlegacy.mixins.json:MixinEnchantmentContainer
# [03:45:25 INFO]: Mixing MixinEnderEyeItem from enigmaticlegacy.mixins.json into net.minecraft.world.item.EnderEyeItem
# [03:45:25 INFO]: Mixing MixinCrossbowItem from enigmaticlegacy.mixins.json into net.minecraft.world.item.CrossbowItem
# [03:45:27 INFO]: Mixing MixinEnderDragon from enigmaticlegacy.mixins.json into net.minecraft.world.entity.boss.enderdragon.EnderDragon
# [03:45:27 INFO]: Renaming synthetic method lambda$onTickDeath$0(Lnet/minecraft/server/level/ServerPlayer;)V to md272da1$lambda$onTickDeath$0$0 in enigmaticlegacy.mixins.json:MixinEnderDragon
# [03:45:27 INFO]: Mixing MixinShulker from enigmaticlegacy.mixins.json into net.minecraft.world.entity.monster.Shulker
# [03:45:27 INFO]: Mixing MixinVillagerEntity from enigmaticlegacy.mixins.json into net.minecraft.world.entity.npc.Villager
# [03:45:27 INFO]: Mixing MixinVillager from enigmaticlegacy.mixins.json into net.minecraft.world.entity.npc.Villager
# [03:45:28 INFO]: Mixing MixinBindingCurseEnchantment from enigmaticlegacy.mixins.json into net.minecraft.world.item.enchantment.BindingCurseEnchantment
# TEST
# TEST2
# [03:45:32 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.insanelib.module.base.feature.TagsFeature
# [03:45:32 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.insanelib.module.base.feature.FixFeature
# [03:45:32 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.insanelib.module.base.feature.AEC3DFeature
# Temporary Spawners loaded.
# [03:45:32 INFO]: Loaded maxhealthfix for Forge.
# [03:45:32 INFO]: Creating Creative Tab...
# [03:45:32 INFO]: Initializing registration handler and mod config.
# [03:45:33 INFO]: Registering common setup handler, and load complete handler.
# [03:45:33 INFO]: Registering server setup handler.
# [03:45:33 INFO]: Registering the reload listener.
# [03:45:33 INFO]: Registering mod class to forge events.
# [03:45:33 INFO]: Fixing MC-151457. Crafting remainder for minecraft:pufferfish_bucket is now minecraft:bucket.
# [03:45:33 INFO]: Fixing MC-151457. Crafting remainder for minecraft:salmon_bucket is now minecraft:bucket.
# [03:45:33 INFO]: Fixing MC-151457. Crafting remainder for minecraft:cod_bucket is now minecraft:bucket.
# [03:45:33 INFO]: Fixing MC-151457. Crafting remainder for minecraft:tropical_fish_bucket is now minecraft:bucket.
# [03:45:33 INFO]: Fixing MC-151457. Crafting remainder for minecraft:axolotl_bucket is now minecraft:bucket.
# [03:45:33 INFO]: Fixing MC-151457. Crafting remainder for minecraft:powder_snow_bucket is now minecraft:bucket.
# [03:45:33 INFO]: Fixing MC-151457. Crafting remainder for minecraft:tadpole_bucket is now minecraft:bucket.
# [03:45:33 INFO]: Mixing MixinPlayerList from enigmaticlegacy.mixins.json into net.minecraft.server.players.PlayerList
# TEST
# TEST2
# [03:45:33 WARN]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/valhelsia_structures-common.toml is not correct. Correcting
# [03:45:33 WARN]: Incorrect key structures was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:33 WARN]: Incorrect key structures.global was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:33 WARN]: Incorrect key structures.global.flatness_delta was corrected from null to its default, 4.
# [03:45:33 WARN]: Incorrect key structures.global.min_structure_distance was corrected from null to its default, 5.
# [03:45:33 WARN]: Incorrect key structures.global.default_margin was corrected from null to its default, 12.
# [03:45:33 WARN]: Incorrect key blocks was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:33 WARN]: Incorrect key blocks.doused_torch was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:33 WARN]: Incorrect key blocks.doused_torch.disable was corrected from null to its default, false.
# [03:45:33 WARN]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/valhelsia_structures-client.toml is not correct. Correcting
# [03:45:33 WARN]: Incorrect key furniture_warning was corrected from null to its default, true.
# [03:45:33 INFO]: Constructing common components for swordblockingmechanics:main
# [03:45:34 INFO]: Hello world!
# [03:45:34 INFO]: Constructing mod instance...
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.witch.WitchFleeTarget
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.witch.throwing.WitchPotionThrowing
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.witch.ThirstyWitches
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.witch.darkart.DarkArtWitch
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.villager.VillagerAttacking
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.spider.webber.ThrowingWeb
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.spider.Misc
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.slime.Slimes
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.skeleton.WitherSkeletons
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.skeleton.SkeletonFleeTarget
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.skeleton.shoot.SkeletonShoot
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.shulker.ShulkerBullets
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.shulker.shulkerattack.ShulkerAttack
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.shulker.ShulkerArmor
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.shulker.feature.ShulkerBullets
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.pets.Wolves
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.pets.snowgolem.SnowGolems
# [03:45:34 INFO]: Registering C2S receiver with id architectury:sync_ids
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.pets.IronGolems
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.WardenInteractions
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.targeting.Targeting
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.Spawning
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.riding.Riding
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.pearler.PearlerMobs
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.OpenDoors
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.movement.Movement
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.miner.MinerMobs
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.MeleeAttacking
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.leap.Leap
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.ItemDisruption
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.flee.Flee
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.fisher.FisherMobs
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.bugs.silverfish.SilverfishFeature
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.breakanger.BreakAnger
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.BitingMobs
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.avoidexplosion.AvoidExplosions
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.Attacking
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.mobs.anticheese.AntiCheese
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.illager.shoot.PillagerShoot
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.illager.RavagerFeature
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.illager.PillagerFleeTarget
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.ghast.GhastShoot
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.enderman.getoverhere.GetOverHere
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.drowned.DrownedSwimming
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.creeper.CreeperSwell
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.blaze.BlazeAttack
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.animal.NotTemptedAnimals
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.animal.AnimalsGroupFlee
# [03:45:34 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.animal.AnimalScaredAttack
# [03:45:34 INFO]: Mod instance constructed successfully.
# [03:45:34 INFO]: Mixing MixinEnterBlockTrigger from enigmaticlegacy.mixins.json into net.minecraft.advancements.critereon.EnterBlockTrigger
# [03:45:34 INFO]: Mixing MixinInventoryChangeTrigger from enigmaticlegacy.mixins.json into net.minecraft.advancements.critereon.InventoryChangeTrigger
# [03:45:34 INFO]: Mixing MixinSummonedEntityTrigger from enigmaticlegacy.mixins.json into net.minecraft.advancements.critereon.SummonedEntityTrigger
# [03:45:34 ERROR]: Could not find parent net/minecraft/client/renderer/entity/layers/RenderLayer for class com/obscuria/obscureapi/client/renderer/PatreonLayer in classloader cpw.mods.modlauncher.TransformingClassLoader@745926c3 on thread Thread[#37,modloading-worker-0,5,main]
# [03:45:34 INFO]: Registered 2 network packets
# [03:45:34 WARN]: Class not found! Ignoring clause
# [03:45:34 WARN]: Class not found! Ignoring clause
# [03:45:34 WARN]: Class not found! Ignoring clause
# [03:45:34 WARN]: Class not found! Ignoring clause
# [03:45:34 WARN]: Class not found! Ignoring clause
# [03:45:34 WARN]: Class not found! Ignoring clause
# [03:45:34 ERROR]: An error occurred building event handler
# java.lang.ClassNotFoundException: net.minecraft.client.renderer.entity.layers.RenderLayer
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:157) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.buildEvents(EventSubclassTransformer.java:97) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.transform(EventSubclassTransformer.java:48) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventBusEngine.processClass(EventBusEngine.java:26) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.service.ModLauncherService.processClassWithFlags(ModLauncherService.java:32) ~[eventbus-6.0.5.jar:6.0.5+0+master.c510e2cc]
# 	at cpw.mods.modlauncher.LaunchPluginHandler.offerClassNodeToPlugins(LaunchPluginHandler.java:88) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.ClassTransformer.transform(ClassTransformer.java:120) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.TransformingClassLoader.maybeTransformClassBytes(TransformingClassLoader.java:50) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.readerToClass(ModuleClassLoader.java:121) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.lambda$findClass$15(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadFromModule(ModuleClassLoader.java:267) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.findClass(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:144) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at java.lang.ClassLoader.defineClass0(Native Method) ~[?:?]
# 	at java.lang.System$2.defineClass(System.java:2394) ~[?:?]
# 	at java.lang.invoke.MethodHandles$Lookup$ClassDefiner.defineClass(MethodHandles.java:2505) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.generateInnerClass(InnerClassLambdaMetafactory.java:361) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.spinInnerClass(InnerClassLambdaMetafactory.java:286) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.buildCallSite(InnerClassLambdaMetafactory.java:221) ~[?:?]
# 	at java.lang.invoke.LambdaMetafactory.metafactory(LambdaMetafactory.java:341) ~[?:?]
# 	at java.lang.invoke.BootstrapMethodInvoker.invoke(BootstrapMethodInvoker.java:134) ~[?:?]
# 	at java.lang.invoke.CallSite.makeSite(CallSite.java:316) ~[?:?]
# 	at java.lang.invoke.MethodHandleNatives.linkCallSiteImpl(MethodHandleNatives.java:274) ~[?:?]
# 	at java.lang.invoke.MethodHandleNatives.linkCallSite(MethodHandleNatives.java:264) ~[?:?]
# 	at com.obscuria.obscureapi.client.renderer.PatreonLayer$Mode.<clinit>(PatreonLayer.java:55) ~[obscure_api-15.jar%23370!/:com.obscuria]
# 	at com.obscuria.obscureapi.ObscureAPIConfig$Client.<clinit>(ObscureAPIConfig.java:28) ~[obscure_api-15.jar%23370!/:com.obscuria]
# 	at com.obscuria.obscureapi.ObscureAPIConfig.register(ObscureAPIConfig.java:46) ~[obscure_api-15.jar%23370!/:com.obscuria]
# 	at com.obscuria.obscureapi.ObscureAPI.<init>(ObscureAPI.java:69) ~[obscure_api-15.jar%23370!/:com.obscuria]
# 	at jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:502) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:486) ~[?:?]
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.constructMod(FMLModContainer.java:76) ~[javafmllanguage-1.20.1-47.2.20.jar%23408!/:?]
# 	at net.minecraftforge.fml.ModContainer.lambda$buildTransitionHandler$10(ModContainer.java:123) ~[fmlcore-1.20.1-47.2.20.jar%23407!/:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.run(CompletableFuture.java:1804) [?:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.exec(CompletableFuture.java:1796) [?:?]
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?]
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?]
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?]
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?]
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?]
# [03:45:34 ERROR]: Attempted to load class com/obscuria/obscureapi/client/renderer/PatreonLayer for invalid dist DEDICATED_SERVER
# [03:45:35 WARN]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/invtweaks-client.toml is not correct. Correcting
# [03:45:35 WARN]: Incorrect key sorting was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:35 WARN]: Incorrect key sorting.category was corrected from null to its default, [SimpleCommentedConfig:{name=sword, spec=[/instanceof:net.minecraft.item.SwordItem]}, SimpleCommentedConfig:{name=axe, spec=[/instanceof:net.minecraft.item.AxeItem]}, SimpleCommentedConfig:{name=pickaxe, spec=[/instanceof:net.minecraft.item.PickaxeItem]}, SimpleCommentedConfig:{name=shovel, spec=[/instanceof:net.minecraft.item.ShovelItem]}, SimpleCommentedConfig:{name=acceptableFood, spec=[/instanceof:net.minecraft.item.Food; !minecraft:rotten_flesh; !minecraft:spider_eye; !minecraft:poisonous_potato; !minecraft:pufferfish]}, SimpleCommentedConfig:{name=torch, spec=[minecraft:torch]}, SimpleCommentedConfig:{name=cheapBlocks, spec=[/tag:minecraft:cobblestone, /tag:minecraft:dirt]}, SimpleCommentedConfig:{name=blocks, spec=[/instanceof:net.minecraft.item.BlockItem]}].
# [03:45:35 WARN]: Incorrect key sorting.rules was corrected from null to its default, [D /LOCKED, A1-C9 /OTHER].
# [03:45:35 WARN]: Incorrect key sorting.containerOverrides was corrected from null to its default, [SimpleCommentedConfig:{containerClass=com.tfar.craftingstation.CraftingStationContainer, sortRange=}, SimpleCommentedConfig:{containerClass=tfar.dankstorage.container.DankContainers, sortRange=}, SimpleCommentedConfig:{containerClass=mcjty.rftoolsutility.modules.crafter.blocks.CrafterContainer, sortRange=}, SimpleCommentedConfig:{containerClass=appeng.container.implementations.InterfaceTerminalContainer, sortRange=}, SimpleCommentedConfig:{containerClass=appeng.container.implementations.CraftingTermContainer, sortRange=}, SimpleCommentedConfig:{containerClass=appeng.container.implementations.PatternTermContainer, sortRange=}, SimpleCommentedConfig:{containerClass=appeng.container.implementations.WirelessTermContainer, sortRange=}, SimpleCommentedConfig:{containerClass=net.blay09.mods.excompressum.container.AutoSieveContainer, sortRange=}].
# [03:45:35 WARN]: Incorrect key tweaks was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:35 WARN]: Incorrect key tweaks.autoRefill was corrected from null to its default, true.
# [03:45:35 WARN]: Incorrect key tweaks.quickView was corrected from null to its default, true.
# [03:45:35 WARN]: Incorrect key tweaks.enableSort was corrected from null to its default, 3.
# [03:45:35 WARN]: Incorrect key tweaks.enableButtons was corrected from null to its default, 3.
# [03:45:35 INFO]: Farmers Delight's compatibility has been initialized!
# [03:45:35 INFO]: Registering C2S receiver with id artifacts:networking_channel/42a7ad70b1cc371599a0eff744096b8a
# [03:45:35 INFO]: Registering C2S receiver with id artifacts:networking_channel/74a5e841822a3a87854ae896a33430d6
# [03:45:35 INFO]: Registering C2S receiver with id artifacts:networking_channel/eb3d1e2748533430848cadf0f37c7e9c
# [03:45:35 INFO]: Registering C2S receiver with id artifacts:networking_channel/91c8520f19f93b3e8b6a727568e194ab
# [03:45:35 INFO]: Registering C2S receiver with id artifacts:networking_channel/8c2784d778293fd482ed84b8aa5fedb9
# [03:45:35 INFO]: forge loader environment detected
# [03:45:35 INFO]: Forge mod loading, version 47.2.20, for MC 1.20.1 with MCP 20230612.114412
# [03:45:35 INFO]: MinecraftForge v47.2.20 Initialized
# [03:45:35 INFO]: NeoForge v47.2.20 Initialized
# [03:45:35 INFO]: Mohist mod loading.....
# [03:45:35 INFO]: EventDispatcherRegistry initialized
# [03:45:35 INFO]: Constructing common components for cutthrough:main
# [Mouse Tweaks] Disabled because not running on the client.
# /workspaces/codespaces-jupyter/Minecraft-server/config
# TEST
# TEST2
# [03:45:36 WARN]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/forbidden_arcanus-client.toml is not correct. Correcting
# [03:45:36 WARN]: Incorrect key rendering was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key rendering.orb_of_temporary_flight was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key rendering.orb_of_temporary_flight.render was corrected from null to its default, true.
# [03:45:36 WARN]: Incorrect key rendering.orb_of_temporary_flight.x_position was corrected from null to its default, 1.
# [03:45:36 WARN]: Incorrect key rendering.orb_of_temporary_flight.y_position was corrected from null to its default, 1.
# [03:45:36 WARN]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/forbidden_arcanus-common.toml is not correct. Correcting
# [03:45:36 WARN]: Incorrect key items was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key items.orb_of_temporary_flight was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key items.orb_of_temporary_flight.time was corrected from null to its default, 6000.
# [03:45:36 WARN]: Incorrect key items.edelwood_bucket was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key items.edelwood_bucket.water_capacity was corrected from null to its default, 4.
# [03:45:36 WARN]: Incorrect key items.edelwood_bucket.lava_capacity was corrected from null to its default, 3.
# [03:45:36 WARN]: Incorrect key items.edelwood_bucket.milk_capacity was corrected from null to its default, 4.
# [03:45:36 WARN]: Incorrect key items.edelwood_bucket.soup_capacity was corrected from null to its default, 8.
# [03:45:36 WARN]: Incorrect key items.boom_arrow was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key items.boom_arrow.block_damage was corrected from null to its default, false.
# [03:45:36 WARN]: Incorrect key items.boom_arrow.explosion_radius was corrected from null to its default, 3.
# [03:45:36 WARN]: Incorrect key items.mundabitur_dust was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key items.mundabitur_dust.charge_creeper was corrected from null to its default, true.
# [03:45:36 WARN]: Incorrect key items.xpetrified_orb was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key items.xpetrified_orb.experience_points was corrected from null to its default, 91.
# [03:45:36 WARN]: Incorrect key items.eternal_stella was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key items.eternal_stella.uses was corrected from null to its default, 3.
# [03:45:36 WARN]: Incorrect key blocks was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key blocks.stella_arcanum was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key blocks.stella_arcanum.explode was corrected from null to its default, true.
# [03:45:36 WARN]: Incorrect key blocks.stella_arcanum.block_damage was corrected from null to its default, true.
# [03:45:36 WARN]: Incorrect key blocks.stella_arcanum.explosion_radius was corrected from null to its default, 3.
# [03:45:36 WARN]: Incorrect key blocks.edelwood_ladder was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key blocks.edelwood_ladder.speed was corrected from null to its default, 2.0.
# [03:45:36 WARN]: Incorrect key enchantments was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key enchantments.eternal was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key enchantments.eternal.repair_item was corrected from null to its default, true.
# [03:45:36 WARN]: Incorrect key aureal was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key aureal.corruption was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key aureal.corruption.disable_consequences was corrected from null to its default, false.
# [03:45:36 WARN]: Incorrect key aureal.corruption.entity_death_increasement_amount was corrected from null to its default, 1.
# [03:45:36 WARN]: Incorrect key aureal.corruption.aureal_entity_death_increasement_amount was corrected from null to its default, 3.
# [03:45:36 WARN]: Incorrect key aureal.corruption.entity_death_increasement_chance was corrected from null to its default, 0.35.
# [03:45:36 WARN]: Incorrect key aureal.corruption.aureal_entity_death_increasement_chance was corrected from null to its default, 0.42.
# [03:45:36 WARN]: Incorrect key aureal.corruption.natural_decreasement was corrected from null to its default, true.
# [03:45:36 WARN]: Incorrect key aureal.corruption.natural_decreasement_time was corrected from null to its default, 6000.
# [03:45:36 WARN]: Incorrect key aureal.corruption.breeding_decreasement_chance was corrected from null to its default, 0.45.
# [03:45:36 WARN]: Incorrect key aureal.aureal_entity_chance was corrected from null to its default, 0.25.
# [03:45:36 INFO]: Constructing common components for leavemybarsalone:main
# [03:45:36 WARN]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/zeta-common.toml is not correct. Correcting
# [03:45:36 WARN]: Incorrect key general was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:36 WARN]: Incorrect key general.Use Anti Overlap was corrected from null to its default, true.
# [03:45:36 WARN]: Incorrect key general.Use Piston Logic Replacement was corrected from null to its default, true.
# [03:45:36 WARN]: Incorrect key general.Piston Push Limit was corrected from null to its default, 12.
# [03:45:36 WARN]: Incorrect key general.Hide Disabled Content was corrected from null to its default, true.
# [03:45:36 WARN]: Incorrect key general.Enable Jei Item Info was corrected from null to its default, true.
# [03:45:36 WARN]: Incorrect key general.Suppressed Info was corrected from null to its default, [].
# [03:45:36 WARN]: Incorrect key general.Enable Advancement Modification was corrected from null to its default, true.
# [03:45:36 WARN]: Incorrect key general.Enable Modded Advancements was corrected from null to its default, true.
# [03:45:36 WARN]: Incorrect key general.Enable Worldgen Watchdog was corrected from null to its default, false.
# [03:45:36 WARN]: Incorrect key general.Use Fast Worldgen was corrected from null to its default, false.
# Library of Exile loaded.
# [03:45:37 WARN]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/appleskin-client.toml is not correct. Correcting
# [03:45:37 WARN]: Incorrect key client was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:37 WARN]: Incorrect key client.showFoodValuesInTooltip was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key client.showFoodValuesInTooltipAlways was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key client.showSaturationHudOverlay was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key client.showFoodValuesHudOverlay was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key client.showFoodValuesHudOverlayWhenOffhand was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key client.showFoodExhaustionHudUnderlay was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key client.showFoodStatsInDebugOverlay was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key client.showFoodHealthHudOverlay was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key client.showVanillaAnimationsOverlay was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key client.maxHudOverlayFlashAlpha was corrected from null to its default, 0.65.
# [03:45:37 WARN]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/lootr-common.toml is not correct. Correcting
# [03:45:37 WARN]: Incorrect key randomise_seed was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key max_age was corrected from null to its default, 6000.
# [03:45:37 WARN]: Incorrect key disable was corrected from null to its default, false.
# [03:45:37 WARN]: Incorrect key skip_unloaded was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key convert_mineshafts was corrected from null to its default, true.
# [03:45:37 INFO]: Initializing TerraBlender underground biome compat
# [03:45:37 WARN]: Incorrect key convert_quark was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key convert_wooden_chests was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key convert_trapped_chests was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key report_unresolved_tables was corrected from null to its default, false.
# [03:45:37 WARN]: Incorrect key additional_chests was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key additional_trapped_chests was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key dimension_whitelist was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key dimension_blacklist was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key modid_dimension_blacklist was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key modid_dimension_whitelist was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key loot_table_blacklist was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key loot_modid_blacklist was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key loot_structure_blacklist was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key disable_break was corrected from null to its default, false.
# [03:45:37 WARN]: Incorrect key enable_break was corrected from null to its default, false.
# [03:45:37 WARN]: Incorrect key check_world_border was corrected from null to its default, false.
# [03:45:37 WARN]: Incorrect key enable_fake_player_break was corrected from null to its default, false.
# [03:45:37 WARN]: Incorrect key power_comparators was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key trapped_custom was corrected from null to its default, false.
# [03:45:37 WARN]: Incorrect key blast_resistant was corrected from null to its default, false.
# [03:45:37 WARN]: Incorrect key blast_immune was corrected from null to its default, false.
# [03:45:37 WARN]: Incorrect key disable_notifications was corrected from null to its default, false.
# [03:45:37 WARN]: Incorrect key notification_delay was corrected from null to its default, 600.
# [03:45:37 WARN]: Incorrect key decay_value was corrected from null to its default, 6000.
# [03:45:37 WARN]: Incorrect key decay_loot_tables was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key decay_modids was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key decay_dimensions was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key decay_structures was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key decay_all was corrected from null to its default, false.
# [03:45:37 WARN]: Incorrect key refresh_value was corrected from null to its default, 24000.
# [03:45:37 WARN]: Incorrect key refresh_loot_tables was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key refresh_modids was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key refresh_dimensions was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key refresh_structures was corrected from null to its default, [].
# [03:45:37 WARN]: Incorrect key refresh_all was corrected from null to its default, false.
# [03:45:37 WARN]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/lootr-client.toml is not correct. Correcting
# [03:45:37 WARN]: Incorrect key vanilla_textures was corrected from null to its default, false.
# [03:45:37 WARN]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/supplementaries-common.toml is not correct. Correcting
# [03:45:37 WARN]: Incorrect key redstone was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:37 WARN]: Incorrect key redstone.speaker_block was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:37 WARN]: Incorrect key redstone.speaker_block.enabled was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.speaker_block.narrator_enabled was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.speaker_block.max_text was corrected from null to its default, 32.
# [03:45:37 WARN]: Incorrect key redstone.speaker_block.range was corrected from null to its default, 64.
# [03:45:37 WARN]: Incorrect key redstone.bellows was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:37 WARN]: Incorrect key redstone.bellows.enabled was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.bellows.base_period was corrected from null to its default, 78.
# [03:45:37 WARN]: Incorrect key redstone.bellows.power_scaling was corrected from null to its default, 2.0.
# [03:45:37 WARN]: Incorrect key redstone.bellows.base_velocity_scaling was corrected from null to its default, 5.0.
# [03:45:37 WARN]: Incorrect key redstone.bellows.velocity_changed_flag was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.bellows.range was corrected from null to its default, 5.
# [03:45:37 WARN]: Incorrect key redstone.spring_launcher was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:37 WARN]: Incorrect key redstone.spring_launcher.enabled was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.spring_launcher.velocity was corrected from null to its default, 1.5.
# [03:45:37 WARN]: Incorrect key redstone.spring_launcher.fall_height_required was corrected from null to its default, 5.
# [03:45:37 WARN]: Incorrect key redstone.enderman_head was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:37 WARN]: Incorrect key redstone.enderman_head.enabled was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.enderman_head.drop_head was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.enderman_head.ticks_to_increase_power was corrected from null to its default, 15.
# [03:45:37 INFO]: Constructing common components for puzzleslib:main
# [03:45:37 WARN]: Incorrect key redstone.enderman_head.work_from_any_side was corrected from null to its default, false.
# [03:45:37 WARN]: Incorrect key redstone.turn_table was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:37 WARN]: Incorrect key redstone.turn_table.enabled was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.turn_table.rotate_entities was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.pulley_block was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:37 WARN]: Incorrect key redstone.pulley_block.enabled was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.pulley_block.mineshaft_elevator was corrected from null to its default, 0.035.
# [03:45:37 WARN]: Incorrect key redstone.dispenser_minecart was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:37 WARN]: Incorrect key redstone.dispenser_minecart.enabled was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.dispenser_minecart.face_forward was corrected from null to its default, false.
# [03:45:37 WARN]: Incorrect key redstone.faucet was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:37 WARN]: Incorrect key redstone.faucet.enabled was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.faucet.spill_items was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.faucet.fill_entities_below was corrected from null to its default, false.
# [03:45:37 WARN]: Incorrect key redstone.wind_vane was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.clock_block was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.redstone_illuminator was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.crank was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.cog_block was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.gold_door was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.gold_trapdoor was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.lock_block was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.crystal_display was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key redstone.relayer was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key functional was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:37 WARN]: Incorrect key functional.rope was corrected from null to its default, SimpleCommentedConfig:{}.
# [03:45:37 WARN]: Incorrect key functional.rope.enabled was corrected from null to its default, true.
# [03:45:37 WARN]: Incorrect key functional.rope.block_side_attachment was corrected from null to its default, true.
# ...
# [03:48:02 INFO]: Preparing spawn area: 35%
# [03:48:03 INFO]: Preparing spawn area: 36%
# [03:48:03 INFO]: Preparing spawn area: 38%
# [03:48:04 INFO]: Preparing spawn area: 41%
# [03:48:04 INFO]: Preparing spawn area: 43%
# [03:48:05 INFO]: Preparing spawn area: 44%
# [03:48:05 INFO]: Preparing spawn area: 47%
# [03:48:06 INFO]: Preparing spawn area: 48%
# [03:48:07 INFO]: Preparing spawn area: 51%
# [03:48:07 INFO]: Preparing spawn area: 54%
# [03:48:07 INFO]: Preparing spawn area: 55%
# [03:48:08 INFO]: Preparing spawn area: 57%
# [03:48:08 INFO]: Preparing spawn area: 58%
# [03:48:09 INFO]: Preparing spawn area: 61%
# [03:48:09 INFO]: Preparing spawn area: 64%
# [03:48:10 INFO]: Preparing spawn area: 67%
# [03:48:10 INFO]: Preparing spawn area: 68%
# [03:48:11 INFO]: Preparing spawn area: 69%
# [03:48:11 INFO]: Preparing spawn area: 72%
# [03:48:12 INFO]: Preparing spawn area: 74%
# [03:48:12 INFO]: Preparing spawn area: 77%
# [03:48:13 INFO]: Preparing spawn area: 80%
# [03:48:13 INFO]: Preparing spawn area: 82%
# [03:48:14 INFO]: Preparing spawn area: 83%
# [03:48:14 INFO]: Preparing spawn area: 85%
# [03:48:15 INFO]: Preparing spawn area: 87%
# [03:48:16 INFO]: Preparing spawn area: 90%
# [03:48:16 INFO]: Preparing spawn area: 92%
# [03:48:16 INFO]: Preparing spawn area: 94%
# [03:48:17 INFO]: Preparing spawn area: 97%
# [03:48:17 INFO]: Time elapsed: 28853 ms
# [03:48:17 INFO]: Preparing start region for dimension minecraft:the_nether
# [03:48:18 INFO]: Preparing spawn area: 0%
# [03:48:18 INFO]: Preparing spawn area: 0%
# [03:48:18 INFO]: Preparing spawn area: 0%
# [03:48:19 INFO]: Preparing spawn area: 0%
# [03:48:20 INFO]: Preparing spawn area: 0%
# [03:48:20 INFO]: Preparing spawn area: 0%
# [03:48:20 INFO]: Preparing spawn area: 0%
# [03:48:21 INFO]: Preparing spawn area: 0%
# [03:48:21 INFO]: Preparing spawn area: 0%
# [03:48:22 INFO]: Preparing spawn area: 0%
# [03:48:22 INFO]: Preparing spawn area: 0%
# [03:48:23 INFO]: Preparing spawn area: 1%
# [03:48:24 INFO]: Preparing spawn area: 1%
# [03:48:24 INFO]: Preparing spawn area: 1%
# [03:48:24 INFO]: Preparing spawn area: 2%
# [03:48:25 INFO]: Preparing spawn area: 2%
# [03:48:25 INFO]: Preparing spawn area: 3%
# [03:48:26 INFO]: Preparing spawn area: 4%
# [03:48:26 INFO]: Preparing spawn area: 5%
# [03:48:27 INFO]: Preparing spawn area: 5%
# [03:48:27 INFO]: Preparing spawn area: 6%
# [03:48:28 INFO]: Preparing spawn area: 8%
# [03:48:28 INFO]: Preparing spawn area: 9%
# [03:48:29 INFO]: Preparing spawn area: 10%
# [03:48:29 INFO]: Preparing spawn area: 10%
# [03:48:30 INFO]: Preparing spawn area: 11%
# [03:48:30 INFO]: CRATER GENERATED AT: -308 0 -182
# [03:48:30 INFO]: Preparing spawn area: 11%
# [03:48:31 INFO]: CRATER GENERATED AT: -385 0 -216
# [03:48:31 INFO]: Preparing spawn area: 12%
# [03:48:31 INFO]: Preparing spawn area: 14%
# [03:48:32 INFO]: Preparing spawn area: 15%
# [03:48:32 INFO]: Preparing spawn area: 16%
# [03:48:33 INFO]: Preparing spawn area: 16%
# [03:48:33 INFO]: Preparing spawn area: 17%
# [03:48:34 INFO]: CRATER GENERATED AT: -466 0 -229
# [03:48:34 INFO]: Preparing spawn area: 18%
# [03:48:34 INFO]: Preparing spawn area: 21%
# [03:48:35 INFO]: Preparing spawn area: 22%
# [03:48:35 INFO]: Preparing spawn area: 23%
# [03:48:36 INFO]: Preparing spawn area: 24%
# [03:48:36 INFO]: Preparing spawn area: 24%
# [03:48:37 INFO]: Preparing spawn area: 25%
# [03:48:37 INFO]: Preparing spawn area: 26%
# [03:48:38 INFO]: Preparing spawn area: 28%
# [03:48:38 INFO]: Preparing spawn area: 30%
# [03:48:39 INFO]: Preparing spawn area: 32%
# [03:48:40 INFO]: Preparing spawn area: 32%
# [03:48:40 INFO]: Preparing spawn area: 32%
# [03:48:40 INFO]: Preparing spawn area: 33%
# [03:48:41 INFO]: Preparing spawn area: 33%
# [03:48:41 INFO]: Preparing spawn area: 34%
# [03:48:42 INFO]: Preparing spawn area: 35%
# [03:48:42 INFO]: Preparing spawn area: 36%
# [03:48:43 INFO]: Preparing spawn area: 37%
# [03:48:43 INFO]: Preparing spawn area: 39%
# [03:48:44 INFO]: Preparing spawn area: 41%
# [03:48:44 INFO]: Preparing spawn area: 42%
# [03:48:45 INFO]: Preparing spawn area: 43%
# [03:48:45 INFO]: Mixing MixinPiglinTasks from enigmaticlegacy.mixins.json into net.minecraft.world.entity.monster.piglin.PiglinAi
# [03:48:45 INFO]: Renaming synthetic method lambda$onPiglinBarter$0(Ljava/util/List;Lnet/minecraft/world/item/ItemStack;)V to md272da1$lambda$onPiglinBarter$0$0 in enigmaticlegacy.mixins.json:MixinPiglinTasks
# [03:48:45 INFO]: Preparing spawn area: 43%
# [03:48:46 INFO]: Preparing spawn area: 44%
# [03:48:46 INFO]: Preparing spawn area: 45%
# [03:48:47 INFO]: Preparing spawn area: 46%
# [03:48:47 INFO]: Preparing spawn area: 47%
# [03:48:47 INFO]: CRATER GENERATED AT: -541 0 -133
# [03:48:48 INFO]: CRATER GENERATED AT: -530 0 -35
# [03:48:48 INFO]: Preparing spawn area: 48%
# [03:48:48 INFO]: Preparing spawn area: 51%
# [03:48:49 INFO]: Preparing spawn area: 53%
# [03:48:49 INFO]: Preparing spawn area: 54%
# [03:48:50 INFO]: Preparing spawn area: 54%
# [03:48:50 INFO]: Preparing spawn area: 55%
# [03:48:51 INFO]: Preparing spawn area: 56%
# [03:48:51 INFO]: Preparing spawn area: 57%
# [03:48:52 INFO]: Preparing spawn area: 58%
# [03:48:52 INFO]: Preparing spawn area: 59%
# [03:48:53 INFO]: Preparing spawn area: 61%
# [03:48:53 INFO]: Preparing spawn area: 63%
# [03:48:54 INFO]: Preparing spawn area: 65%
# [03:48:54 INFO]: Preparing spawn area: 66%
# [03:48:55 INFO]: Preparing spawn area: 66%
# [03:48:55 INFO]: Preparing spawn area: 67%
# [03:48:56 INFO]: Preparing spawn area: 68%
# [03:48:56 INFO]: Preparing spawn area: 68%
# [03:48:57 INFO]: Preparing spawn area: 69%
# [03:48:57 INFO]: Preparing spawn area: 70%
# [03:48:58 INFO]: Preparing spawn area: 71%
# [03:48:58 INFO]: Preparing spawn area: 71%
# [03:48:59 INFO]: Preparing spawn area: 73%
# [03:48:59 INFO]: Preparing spawn area: 74%
# [03:49:00 INFO]: Preparing spawn area: 76%
# [03:49:00 INFO]: Preparing spawn area: 78%
# [03:49:01 INFO]: Preparing spawn area: 79%
# [03:49:01 INFO]: Preparing spawn area: 81%
# [03:49:02 ERROR]: Hanging entity at invalid position: BlockPos{x=147, y=169, z=-166}
# [03:49:02 INFO]: Preparing spawn area: 82%
# [03:49:02 INFO]: CRATER GENERATED AT: -254 0 36
# [03:49:02 INFO]: Preparing spawn area: 82%
# [03:49:03 INFO]: Preparing spawn area: 83%
# [03:49:03 INFO]: Preparing spawn area: 83%
# [03:49:04 INFO]: Preparing spawn area: 84%
# [03:49:04 INFO]: Preparing spawn area: 85%
# [03:49:05 INFO]: Preparing spawn area: 86%
# [03:49:05 INFO]: Preparing spawn area: 86%
# [03:49:05 ERROR]: Hanging entity at invalid position: BlockPos{x=147, y=169, z=-166}
# [03:49:06 INFO]: Preparing spawn area: 88%
# [03:49:06 INFO]: Preparing spawn area: 89%
# [03:49:07 INFO]: CRATER GENERATED AT: -225 0 -322
# [03:49:07 INFO]: Preparing spawn area: 90%
# [03:49:07 INFO]: Preparing spawn area: 93%
# [03:49:08 INFO]: Preparing spawn area: 94%
# [03:49:08 INFO]: Preparing spawn area: 96%
# [03:49:09 INFO]: Preparing spawn area: 97%
# [03:49:09 INFO]: Preparing spawn area: 98%
# [03:49:10 INFO]: Mixing MixinHoglinTasks from enigmaticlegacy.mixins.json into net.minecraft.world.entity.monster.hoglin.HoglinAi
# [03:49:10 INFO]: Preparing spawn area: 98%
# [03:49:10 INFO]: Preparing spawn area: 99%
# [03:49:10 INFO]: Time elapsed: 53044 ms
# [03:49:10 INFO]: Preparing start region for dimension minecraft:the_end
# [03:49:11 INFO]: Preparing spawn area: 0%
# [03:49:11 INFO]: Preparing spawn area: 0%
# [03:49:11 INFO]: Preparing spawn area: 6%
# [03:49:12 INFO]: Preparing spawn area: 31%
# [03:49:12 INFO]: Preparing spawn area: 65%
# [03:49:13 INFO]: Time elapsed: 2459 ms
# [03:49:13 INFO]: Preparing start region for dimension creation_and_adventure:limbo
# [03:49:13 INFO]: Preparing spawn area: 0%
# [03:49:14 INFO]: Preparing spawn area: 0%
# [03:49:14 INFO]: Preparing spawn area: 0%
# [03:49:15 INFO]: Preparing spawn area: 0%
# [03:49:15 INFO]: Preparing spawn area: 0%
# [03:49:16 INFO]: Preparing spawn area: 0%
# [03:49:16 INFO]: Preparing spawn area: 0%
# [03:49:17 INFO]: Preparing spawn area: 0%
# [03:49:17 INFO]: Preparing spawn area: 0%
# [03:49:17 INFO]: Preparing spawn area: 0%
# [03:49:18 INFO]: Preparing spawn area: 0%
# [03:49:19 INFO]: Preparing spawn area: 0%
# [03:49:19 INFO]: Preparing spawn area: 0%
# [03:49:20 INFO]: Preparing spawn area: 0%
# [03:49:20 INFO]: Preparing spawn area: 0%
# [03:49:20 INFO]: Preparing spawn area: 0%
# [03:49:21 INFO]: Preparing spawn area: 1%
# [03:49:22 INFO]: Preparing spawn area: 1%
# [03:49:22 INFO]: Preparing spawn area: 1%
# [03:49:23 INFO]: Preparing spawn area: 2%
# [03:49:23 INFO]: Preparing spawn area: 2%
# [03:49:23 INFO]: Preparing spawn area: 3%
# [03:49:24 INFO]: Preparing spawn area: 4%
# [03:49:24 INFO]: Preparing spawn area: 5%
# [03:49:25 INFO]: Preparing spawn area: 5%
# [03:49:25 INFO]: Preparing spawn area: 6%
# [03:49:26 INFO]: Preparing spawn area: 7%
# [03:49:27 INFO]: Preparing spawn area: 9%
# [03:49:27 INFO]: Preparing spawn area: 9%
# [03:49:28 INFO]: Preparing spawn area: 9%
# [03:49:28 INFO]: Preparing spawn area: 9%
# [03:49:28 INFO]: Preparing spawn area: 10%
# [03:49:29 INFO]: Preparing spawn area: 10%
# [03:49:29 INFO]: Preparing spawn area: 12%
# [03:49:30 INFO]: Preparing spawn area: 14%
# [03:49:30 INFO]: Preparing spawn area: 15%
# [03:49:31 INFO]: Preparing spawn area: 16%
# [03:49:31 INFO]: Preparing spawn area: 19%
# [03:49:32 INFO]: Preparing spawn area: 20%
# [03:49:32 INFO]: Preparing spawn area: 22%
# [03:49:33 INFO]: Preparing spawn area: 23%
# [03:49:33 INFO]: Preparing spawn area: 25%
# [03:49:34 INFO]: Preparing spawn area: 27%
# [03:49:34 INFO]: Preparing spawn area: 28%
# [03:49:35 INFO]: Preparing spawn area: 30%
# [03:49:35 INFO]: Preparing spawn area: 32%
# [03:49:36 INFO]: Preparing spawn area: 33%
# [03:49:36 INFO]: Preparing spawn area: 35%
# [03:49:37 INFO]: Preparing spawn area: 37%
# [03:49:37 INFO]: Preparing spawn area: 38%
# [03:49:38 INFO]: Preparing spawn area: 40%
# [03:49:38 INFO]: Preparing spawn area: 42%
# [03:49:39 INFO]: Preparing spawn area: 43%
# [03:49:39 INFO]: Preparing spawn area: 43%
# [03:49:40 INFO]: Preparing spawn area: 46%
# [03:49:41 INFO]: Preparing spawn area: 47%
# [03:49:42 INFO]: Preparing spawn area: 47%
# [03:49:42 INFO]: Preparing spawn area: 47%
# [03:49:42 INFO]: Preparing spawn area: 48%
# [03:49:43 INFO]: Preparing spawn area: 49%
# [03:49:44 INFO]: Preparing spawn area: 50%
# [03:49:44 INFO]: Preparing spawn area: 50%
# [03:49:44 INFO]: Preparing spawn area: 50%
# [03:49:44 INFO]: Preparing spawn area: 52%
# [03:49:45 INFO]: Preparing spawn area: 54%
# [03:49:46 INFO]: Preparing spawn area: 55%
# [03:49:46 INFO]: Preparing spawn area: 55%
# [03:49:47 INFO]: Preparing spawn area: 58%
# [03:49:47 INFO]: Preparing spawn area: 58%
# [03:49:47 INFO]: Preparing spawn area: 59%
# [03:49:48 INFO]: Preparing spawn area: 61%
# [03:49:49 INFO]: Preparing spawn area: 62%
# [03:49:49 INFO]: Preparing spawn area: 62%
# [03:49:49 INFO]: Preparing spawn area: 62%
# [03:49:50 INFO]: Preparing spawn area: 64%
# [03:49:50 INFO]: Preparing spawn area: 66%
# [03:49:51 INFO]: Preparing spawn area: 68%
# [03:49:51 INFO]: Preparing spawn area: 69%
# [03:49:52 INFO]: Preparing spawn area: 70%
# [03:49:52 INFO]: Preparing spawn area: 72%
# [03:49:53 INFO]: Preparing spawn area: 74%
# [03:49:53 INFO]: Preparing spawn area: 76%
# [03:49:54 INFO]: Preparing spawn area: 78%
# [03:49:55 INFO]: Preparing spawn area: 78%
# [03:49:55 INFO]: Preparing spawn area: 78%
# [03:49:55 INFO]: Preparing spawn area: 80%
# [03:49:56 INFO]: Preparing spawn area: 82%
# [03:49:56 INFO]: Preparing spawn area: 83%
# [03:49:57 INFO]: Preparing spawn area: 84%
# [03:49:57 INFO]: Preparing spawn area: 86%
# [03:49:58 INFO]: Preparing spawn area: 88%
# [03:49:58 INFO]: Preparing spawn area: 88%
# [03:49:59 INFO]: Preparing spawn area: 89%
# [03:49:59 INFO]: Preparing spawn area: 92%
# [03:50:00 INFO]: Preparing spawn area: 93%
# [03:50:00 INFO]: Preparing spawn area: 95%
# [03:50:01 INFO]: Preparing spawn area: 97%
# [03:50:01 INFO]: Preparing spawn area: 99%
# [03:50:01 INFO]: Time elapsed: 48564 ms
# [03:50:01 INFO]: Preparing start region for dimension the_awakening_of_the_elder_souls:the_eclipse
# [03:50:02 INFO]: Preparing spawn area: 0%
# [03:50:02 INFO]: Preparing spawn area: 0%
# [03:50:02 INFO]: Preparing spawn area: 0%
# [03:50:03 INFO]: Preparing spawn area: 0%
# [03:50:03 INFO]: Preparing spawn area: 0%
# [03:50:04 INFO]: Preparing spawn area: 1%
# [03:50:04 INFO]: Preparing spawn area: 1%
# [03:50:05 INFO]: Preparing spawn area: 3%
# [03:50:05 INFO]: Preparing spawn area: 4%
# [03:50:06 INFO]: Preparing spawn area: 6%
# [03:50:06 INFO]: Preparing spawn area: 8%
# [03:50:07 INFO]: Preparing spawn area: 9%
# [03:50:07 INFO]: Preparing spawn area: 11%
# [03:50:08 INFO]: Preparing spawn area: 13%
# [03:50:08 INFO]: Preparing spawn area: 15%
# [03:50:09 INFO]: Preparing spawn area: 15%
# [03:50:09 INFO]: Preparing spawn area: 17%
# [03:50:10 INFO]: Preparing spawn area: 19%
# [03:50:11 INFO]: Preparing spawn area: 20%
# [03:50:11 INFO]: Preparing spawn area: 22%
# [03:50:11 INFO]: Preparing spawn area: 23%
# [03:50:12 INFO]: Preparing spawn area: 24%
# [03:50:12 INFO]: Preparing spawn area: 26%
# [03:50:13 INFO]: Preparing spawn area: 27%
# [03:50:13 INFO]: Preparing spawn area: 30%
# [03:50:14 INFO]: Preparing spawn area: 31%
# [03:50:14 INFO]: Preparing spawn area: 33%
# [03:50:15 INFO]: Preparing spawn area: 36%
# [03:50:15 INFO]: Preparing spawn area: 37%
# [03:50:16 INFO]: Preparing spawn area: 39%
# [03:50:16 INFO]: Preparing spawn area: 42%
# [03:50:17 INFO]: Preparing spawn area: 44%
# [03:50:17 INFO]: Preparing spawn area: 45%
# [03:50:18 INFO]: Preparing spawn area: 47%
# [03:50:18 INFO]: Preparing spawn area: 50%
# [03:50:19 INFO]: Preparing spawn area: 52%
# [03:50:19 INFO]: Preparing spawn area: 54%
# [03:50:20 INFO]: Preparing spawn area: 57%
# [03:50:20 INFO]: Preparing spawn area: 58%
# [03:50:21 INFO]: Preparing spawn area: 60%
# [03:50:21 INFO]: Preparing spawn area: 62%
# [03:50:22 INFO]: Preparing spawn area: 65%
# [03:50:22 INFO]: Preparing spawn area: 67%
# [03:50:23 INFO]: Preparing spawn area: 69%
# [03:50:23 INFO]: Preparing spawn area: 71%
# [03:50:24 INFO]: Preparing spawn area: 72%
# [03:50:24 INFO]: Preparing spawn area: 74%
# [03:50:25 INFO]: Preparing spawn area: 77%
# [03:50:25 INFO]: Preparing spawn area: 80%
# [03:50:26 INFO]: Preparing spawn area: 81%
# [03:50:26 INFO]: Preparing spawn area: 83%
# [03:50:27 INFO]: Preparing spawn area: 86%
# [03:50:27 INFO]: Preparing spawn area: 87%
# [03:50:28 INFO]: Preparing spawn area: 89%
# [03:50:28 INFO]: Preparing spawn area: 91%
# [03:50:29 INFO]: Preparing spawn area: 93%
# [03:50:29 INFO]: Preparing spawn area: 96%
# [03:50:30 INFO]: Preparing spawn area: 99%
# [03:50:30 INFO]: Time elapsed: 28606 ms
# [03:50:30 INFO]: [playit-gg] Enabling playit-gg v0.1.4
# [03:50:32 INFO]: secret key found, checking
# [03:50:32 INFO]: check secret
# [03:50:32 INFO]: [Mohist] Enabling Mohist v1.20.1
# [03:50:32 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [03:50:32 INFO]: Done (257.531s)! For help, type "help"
# [03:50:32 INFO]: Starting remote control listener
# [03:50:32 INFO]: Thread RCON Listener started
# [03:50:32 INFO]: RCON running on 0.0.0.0:25575
# [03:50:32 INFO]: Successfully initialized permission handler forge:default_handler
# [03:50:32 INFO]: Forwarding forge permission[forge:default_handler] to bukkit[mohist:permission]
# [03:50:32 INFO]: Thanks for choosing Incendium!
# [03:50:32 INFO]: Encoded Weapon Attribute registry size (with package overhead): 337750 bytes (in 34 string chunks with the size of 10000)
# [03:50:32 INFO]: Starting Age of Exile Registry auto validation.
# [03:50:32 INFO]: All Age of Exile registries appear valid.
# [03:50:32 INFO]: Sending reload packet to clients
# [03:50:32 INFO]: found minecraft java tunnel: six-dee.joinmc.link
# [03:50:32 INFO]: keys and tunnel setup
# [03:50:32 INFO]: playit.gg: WARNING:  plugin is running with a guest account
# [03:50:32 INFO]: playit.gg: see server console for setup URL
# [03:50:32 INFO]: setup playit.gg account: https://playit.gg/login/guest-account/00010000000000000000000727d965e93988010000000002542bed9b23b61dd30da3481502c630acba1e3e4f77d6e57d0b96e40a8b6db962
# [03:50:32 INFO]: playit.gg: tunnel setup
# [03:50:32 INFO]: playit.gg: six-dee.joinmc.link
# [03:50:33 WARN]: Got IO error working with :control.playit.gg/2602:fbaf:810:0:0:0:0:1, error : java.net.SocketException: Network is unreachable
# [03:50:33 INFO]: request queued, waiting 1 second before resend
# >
